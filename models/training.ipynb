# %%
from sklearn.model_selection import train_test_split
import pandas as pd
#load the dataset
df=pd.read_pickle(r'C:\Users\RISHIKA REDDY\OneDrive\Documents\mini-project\data\merged_isot_data.pkl')
# 80%-train 20% test
train_df ,test_df=train_test_split(df,test_size=0.2,random_state=42,stratify=df['label'])
